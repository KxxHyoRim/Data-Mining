# %% [markdown]
# <a href="https://colab.research.google.com/github/KxxHyoRim/Data-Mining/blob/main/ktx_graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive
# from sklearn.neighbors import KNeighborsClassifier
#불러올 파일의 경로를 filename 변수에 저장
drive.mount('/content/drive')
file_name = '/content/drive/My Drive/Data Mining/ktx_1.csv'

#pandas read_csv로 불러오기
#같은 directory 레벨에 있는 csv 읽어옴
df = pd.read_csv(file_name, encoding='cp949', header=None)
date = df.loc[2]
passenger = df.loc[6]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
date = date[1:]
passenger = passenger[1:]

# %%
date
# Out:
# 1     200501월
# 2     200502월
# 3     200503월
# 4     200504월
# 5     200505월
#        ...
# 68    201008월
# 69    201009월
# 70    201010월
# 71    201011월
# 72    201012월
# Name: 2, Length: 72, dtype: object

# %%
passenger = passenger.astype(int)

# %%
passenger_list = passenger.to_list()

# %%
date_new = []

idx = 0
for i in date:
  date_new.append((i[:-1]))
  # print(date.iloc[idx], end=" / ")
  # print(i[:-1])
  idx += 1

# %%
plt.figure(figsize=(20,10)) # 그래프 사이즈 지정
plt.plot(date_new, passenger,  '-bo')  # 그래프 그리기
plt.xlabel('date') 
plt.ylabel('passenger')
plt.show()
