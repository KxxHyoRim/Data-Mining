# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive


#불러올 파일의 경로를 filename 변수에 저장
drive.mount('/content/drive')
file_name = '/content/drive/My Drive/Data Mining/seoul_0.csv'

#pandas read_csv로 불러오기
df = pd.read_csv(file_name, encoding='cp949')
print(df.shape)
df.head(3)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# (112409, 14)
#                   실거래가아이디  시군구코드  자치구명  ...    건축년도     건물명   건물명.1
# 0  11410-2011-4-0000215-1  11410  서대문구  ...  2007.0  (1-86)  (1-86)
# 1  11440-2011-4-0010594-1  11440   마포구  ...  2000.0   현대홈타운   현대홈타운
# 2  11410-2011-4-0008933-1  11410  서대문구  ...  2001.0  연희소프트빌  연희소프트빌
#
# [3 rows x 14 columns]

# %%
# year = df['건축년도']
# year.value_counts()

# price = df['물건금액']
# price.value_counts()

# %%
# null 값이 있는 row drop
df_drop_row = df.dropna()
df_drop_row.isnull().sum()
# Out:
# 실거래가아이디    0
# 시군구코드      0
# 자치구명       0
# 법정동코드      0
# 법정동명       0
# 신고년도       0
# 건물면적       0
# 층정보        0
# 건물주용도코드    0
# 건물주용도      0
# 물건금액       0
# 건축년도       0
# 건물명        0
# 건물명.1      0
# dtype: int64

# %%
no_year_df = df_drop_row[df_drop_row['건축년도']==0].index
df_drop_row = df_drop_row.drop(no_year_df)
df_drop_row
# Out:
#                        실거래가아이디  시군구코드  자치구명  ...    건축년도          건물명        건물명.1
# 0       11410-2011-4-0000215-1  11410  서대문구  ...  2007.0       (1-86)       (1-86)
# 1       11440-2011-4-0010594-1  11440   마포구  ...  2000.0        현대홈타운        현대홈타운
# 2       11410-2011-4-0008933-1  11410  서대문구  ...  2001.0       연희소프트빌       연희소프트빌
# 3       11440-2011-4-0010590-1  11440   마포구  ...  1976.0     (652-11)     (652-11)
# 5       11440-2011-4-0010586-1  11440   마포구  ...  2011.0         동삼빌라         동삼빌라
# ...                        ...    ...   ...  ...     ...          ...          ...
# 112404  11380-2011-4-0015901-1  11380   은평구  ...  1991.0           태택           태택
# 112405  11380-2011-4-0015902-1  11380   은평구  ...  2011.0  영화빌리지(3-13)  영화빌리지(3-13)
# 112406  11380-2011-4-0015904-1  11380   은평구  ...  2011.0        힐튼렉스빌        힐튼렉스빌
# 112407  11380-2011-4-0015911-1  11380   은평구  ...  2008.0         명성캐슬         명성캐슬
# ...

# %%
plt.figure(figsize=(20,10)) # 그래프 사이즈 지정
plt.ㅌscatter(df_drop_row['건축년도'], df_drop_row['물건금액'])  # 그래프 그리기

plt.xlabel('year') 
plt.ylabel('price')
plt.show()
